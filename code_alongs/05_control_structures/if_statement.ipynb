# %% [markdown]
# # if-statements

# %%
age = 17.999
age_limit = 18

if age >= age_limit:
    print("Welcome to the pub")
else:
    print("You are too young")

print("Program continues here ...")
# Out:
# You are too young
# Program continues here ...

# %%
# Balder 
# Requirement: 140cm and less than 190cm
# At least 12 years

height = 140
age = 14

if height < 140 or height > 190 and age < 12:
    print("You don't meed requirement")
else:
    print("Enjoy the ride")
# Out:
# Enjoy the ride

# %%
height = 140 
age = 12

if 140 < height < 190 and age < 12:
    print("You don't meed requirement")
else:
    print("Enjoy the ride")
# Out:
# Enjoy the ride
