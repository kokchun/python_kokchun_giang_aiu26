# %% [markdown]
# # while statement
#
# - loops when condition is True
# - "if-loop"

# %%
i = 0

while i < 5:
    print("hej")
    i += 1 # increments i in each iteration
# Out:
# hej
# hej
# hej
# hej
# hej
