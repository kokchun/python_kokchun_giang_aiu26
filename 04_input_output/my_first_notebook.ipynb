# %% [markdown]
# # Inputs and outputs

# %%
print("Det här fungerar")
# Out:
# Det här fungerar

# %%
# this is a variable called name with the value "Kokchun"
name = "Kokchun"

print(name)
# Out:
# Kokchun

# %%
print(f"Hello {name}")
# Out:
# Hello Kokchun

# %%
name = "Anna"
age = 17
hobby = "chess"
has_rabbit = True

print(f"This is {name}")
print(f"She is {age} years old")
print(f"Her hobby is {hobby}")
print(f"She has a rabbit? {has_rabbit}")
# Out:
# This is Anna
# She is 17 years old
# Her hobby is chess
# She has a rabbit? True

# %% [markdown]
# ## Inputs

# %%
name = input("Enter your name: ")
print(f"Hello {name}")
# Out:
# Hello David

# %%
gravity = 9.82
# needs to convert to int to be able to do calculations
mass = int(input("Enter your weight in kg: "))

force = mass*gravity

print(f"Your force is {force}N")
# Out:
# Your force is 648.12N

# %%
import math

PI = math.pi

radius = 1
perimeter = 2*PI*radius
# **2 means to the power of 2
area = PI*radius**2

print(f"radius is {radius}, perimeter is {perimeter}, area is {area}")
# Out:
# radius is 1, perimeter is 6.283185307179586, area is 3.141592653589793
